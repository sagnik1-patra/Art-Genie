# %%
import os
import re
import json
import yaml
import logging
import warnings
from typing import List
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, f1_score, top_k_accuracy_score,
    confusion_matrix
)
import joblib

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
warnings.filterwarnings("ignore", category=FutureWarning)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# -----------------------------
# Paths
# -----------------------------
CSV_PATH     = r"C:\Users\sagni\Downloads\Art Genie\archive\wikiart_scraped.csv"
ARTIFACT_DIR = r"C:\Users\sagni\Downloads\Art Genie"

PKL_PATH       = os.path.join(ARTIFACT_DIR, "artgenie_textclf.pkl")
H5_PATH        = os.path.join(ARTIFACT_DIR, "artgenie_textclf.h5")
CONFIG_YAML    = os.path.join(ARTIFACT_DIR, "artgenie_config.yaml")
METRICS_JSON   = os.path.join(ARTIFACT_DIR, "metrics.json")
PRED_SAMPLE    = os.path.join(ARTIFACT_DIR, "sample_predictions.csv")
LABELS_JSON    = os.path.join(ARTIFACT_DIR, "label_mapping.json")
HISTORY_CSV    = os.path.join(ARTIFACT_DIR, "history.csv")
CONF_FULL_CSV  = os.path.join(ARTIFACT_DIR, "confusion_matrix_full.csv")
ACC_PNG        = os.path.join(ARTIFACT_DIR, "accuracy_curve.png")
HEATMAP_PNG    = os.path.join(ARTIFACT_DIR, "confusion_heatmap_top25.png")

logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s | %(message)s")

# -----------------------------
# Helpers
# -----------------------------
POSSIBLE_TEXT_COLS = [
    "title","description","caption","tags","genre","style","artist",
    "movement","content","about","wiki","text","meta","materials","subject"
]
POSSIBLE_LABEL_COLS = ["style","genre","artist"]

def ensure_dir(p): os.makedirs(p, exist_ok=True)

def normalize_cols(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df.columns = [str(c).strip().lower().replace(" ", "_") for c in df.columns]
    return df

def canonicalize(s: str) -> str:
    return re.sub(r"\s+", " ", str(s).lower()).strip()

def pick_label_column(df: pd.DataFrame) -> str:
    for c in POSSIBLE_LABEL_COLS:
        if c in df.columns and df[c].notna().any():
            return c
    if "label" in df.columns:
        return "label"
    raise ValueError("No suitable label column found (expected one of: style/genre/artist/label).")

def collect_text_columns(df: pd.DataFrame) -> List[str]:
    cols = [c for c in POSSIBLE_TEXT_COLS if c in df.columns]
    if not cols:
        cols = [c for c in df.columns if df[c].dtype == object]
    return cols[:8]

def build_text_series(df: pd.DataFrame, text_cols: List[str]) -> pd.Series:
    if not text_cols: raise ValueError("No text columns found.")
    parts = [df[c].astype(str) for c in text_cols]
    txt = parts[0]
    for p in parts[1:]:
        txt = txt.str.cat(p, sep=" . ", na_rep="")
    return txt.fillna("").map(lambda s: re.sub(r"\s+", " ", str(s)).strip())

def filter_min_samples(df: pd.DataFrame, label_col: str, min_count: int = 8) -> pd.DataFrame:
    vc = df[label_col].value_counts()
    keep = set(vc[vc >= min_count].index)
    filtered = df[df[label_col].isin(keep)].copy()
    dropped = len(df) - len(filtered)
    if dropped > 0:
        logging.info(f"Filtered {dropped} rows due to rare classes (<{min_count}). Remaining classes: {len(keep)}")
    return filtered

# -----------------------------
# Keras model (text-only)
# -----------------------------
def build_keras_text_model(vocab_size: int, max_len: int, num_classes: int) -> keras.Model:
    text_inp = keras.Input(shape=(1,), dtype=tf.string, name="text")
    vectorizer = layers.TextVectorization(
        max_tokens=vocab_size,
        output_mode="int",
        output_sequence_length=max_len,
        standardize="lower_and_strip_punctuation",
        split="whitespace"
    )
    x = vectorizer(text_inp)
    x = layers.Embedding(vocab_size, 128, name="embed")(x)
    x = layers.Conv1D(128, 5, padding="same", activation="relu")(x)
    x = layers.GlobalMaxPool1D()(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(num_classes, activation="softmax", name="label")(x)

    model = keras.Model(text_inp, out)
    # Sparse-friendly metrics for integer labels
    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(k=3, name="top3_acc"),
        ],
    )
    model.vectorizer = vectorizer
    return model

# -----------------------------
# Plotting
# -----------------------------
def plot_accuracy(history_csv: str, out_png: str, also_show: bool = True):
    hist = pd.read_csv(history_csv)
    # we saved: epoch, loss, accuracy, top3_acc, val_loss, val_accuracy, val_top3_acc (if present)
    plt.figure(figsize=(9, 6))
    if "accuracy" in hist.columns:
        plt.plot(hist["epoch"], hist["accuracy"], label="Train Accuracy")
    if "val_accuracy" in hist.columns:
        plt.plot(hist["epoch"], hist["val_accuracy"], label="Val Accuracy")
    plt.title("Training Accuracy")
    plt.xlabel("Epoch"); plt.ylabel("Accuracy")
    plt.legend(); plt.grid(True, linestyle="--", linewidth=0.5)
    plt.tight_layout(); plt.savefig(out_png, dpi=160)
    if also_show:
        try: plt.show()
        except Exception: pass
    plt.close()

def plot_confusion_heatmap(y_true, y_pred, class_names, out_png: str, top_k: int = 25, also_show: bool = True):
    """
    For readability, select top_k most frequent classes in y_true,
    build a sub-confusion-matrix and plot it as a heatmap.
    Also saves the full confusion matrix separately as CSV.
    """
    cm_full = confusion_matrix(y_true, y_pred, labels=np.arange(len(class_names)))
    # Save full confusion matrix CSV with headers
    df_full = pd.DataFrame(cm_full, index=class_names, columns=class_names)
    df_full.to_csv(CONF_FULL_CSV, encoding="utf-8")

    # Top-K by true frequency
    true_counts = np.asarray(cm_full.sum(axis=1)).ravel()
    top_idx = np.argsort(true_counts)[::-1][:min(top_k, len(class_names))]
    top_labels = [class_names[i] for i in top_idx]
    cm_top = cm_full[np.ix_(top_idx, top_idx)]

    plt.figure(figsize=(12, 10))
    im = plt.imshow(cm_top, interpolation="nearest", aspect="auto")
    plt.colorbar(im, fraction=0.046, pad=0.04)
    plt.title(f"Confusion Matrix Heatmap (Top {len(top_labels)} Classes)")
    plt.xticks(range(len(top_labels)), top_labels, rotation=90)
    plt.yticks(range(len(top_labels)), top_labels)
    plt.tight_layout(); plt.savefig(out_png, dpi=160)
    if also_show:
        try: plt.show()
        except Exception: pass
    plt.close()

# -----------------------------
# Main (train + plot)
# -----------------------------
def main():
    ensure_dir(ARTIFACT_DIR)
    if not os.path.exists(CSV_PATH):
        raise FileNotFoundError(f"CSV not found: {CSV_PATH}")

    logging.info(f"Reading CSV: {CSV_PATH}")
    df = pd.read_csv(CSV_PATH, engine="python")
    df = normalize_cols(df)

    label_col = pick_label_column(df)
    text_cols = collect_text_columns(df)
    logging.info(f"Using label column: '{label_col}'")
    logging.info(f"Using text columns: {text_cols}")

    df["__text__"] = build_text_series(df, text_cols)
    df[label_col] = df[label_col].astype(str).map(canonicalize)
    df = df[(df["__text__"].str.len() > 0) & (df[label_col].str.len() > 0)].copy()
    df = filter_min_samples(df, label_col, min_count=8)
    if df.empty:
        raise ValueError("No data left after filtering. Relax min_count or check CSV.")

    X_text = df["__text__"].values
    y_raw  = df[label_col].values
    le = LabelEncoder()
    y = le.fit_transform(y_raw)
    class_names = list(le.classes_)
    num_classes = len(class_names)
    logging.info(f"Num classes: {num_classes}")

    X_train, X_val, y_train, y_val = train_test_split(
        X_text, y, test_size=0.2, random_state=42, stratify=y
    )

    # 1) sklearn pipeline → PKL
    logging.info("[SKLEARN] Fitting TF-IDF + LogisticRegression...")
    sk_pipe = Pipeline([
        ("tfidf", TfidfVectorizer(
            max_features=100_000, ngram_range=(1, 2),
            lowercase=True, strip_accents="unicode", min_df=2
        )),
        ("logreg", LogisticRegression(max_iter=1000, n_jobs=-1 if hasattr(LogisticRegression, "n_jobs") else None))
    ])
    sk_pipe.fit(X_train, y_train)

    y_prob_sk = None
    try:
        y_prob_sk = sk_pipe.predict_proba(X_val)
        y_pred_sk = np.argmax(y_prob_sk, axis=1)
    except Exception:
        y_pred_sk = sk_pipe.predict(X_val)

    acc_sk = float(accuracy_score(y_val, y_pred_sk))
    f1_sk  = float(f1_score(y_val, y_pred_sk, average="weighted"))
    top3_sk = float(top_k_accuracy_score(y_val, y_prob_sk, k=3)) if y_prob_sk is not None else None

    joblib.dump({"pipeline": sk_pipe, "label_encoder": le}, PKL_PATH)
    logging.info(f"[SKLEARN] Saved → {PKL_PATH}")

    # 2) Keras model → H5
    logging.info("[KERAS] Building & training text classifier...")
    VOCAB_SIZE = 40_000
    MAX_LEN = 128
    keras_model = build_keras_text_model(VOCAB_SIZE, MAX_LEN, num_classes)

    # adapt vectorizer
    keras_model.vectorizer.adapt(tf.data.Dataset.from_tensor_slices(X_train).batch(256))

    def make_ds(texts, labels, train=True):
        ds = tf.data.Dataset.from_tensor_slices((texts, labels))
        if train: ds = ds.shuffle(8192, reshuffle_each_iteration=True)
        return ds.batch(256).prefetch(tf.data.AUTOTUNE)

    ds_train = make_ds(X_train, y_train, train=True)
    ds_val   = make_ds(X_val, y_val, train=False)

    es = keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=5, restore_best_weights=True)
    hist = keras_model.fit(ds_train, validation_data=ds_val, epochs=25, verbose=0, callbacks=[es])

    # Evaluate & save model
    eval_res = keras_model.evaluate(ds_val, verbose=0)  # [loss, accuracy, top3_acc]
    acc_keras   = float(eval_res[1]) if len(eval_res) > 1 else None
    top3_keras  = float(eval_res[2]) if len(eval_res) > 2 else None
    keras_model.save(H5_PATH); logging.info(f"[KERAS] Saved → {H5_PATH}")

    # Save training history (for plotting)
    hist_df = pd.DataFrame(hist.history)
    # ensure epoch column
    hist_df.insert(0, "epoch", np.arange(1, len(hist_df)+1))
    hist_df.to_csv(HISTORY_CSV, index=False)

    # Sample predictions CSV (200 rows)
    if y_prob_sk is not None:
        top1_idx  = np.argmax(y_prob_sk, axis=1)
        top1_lbl  = le.inverse_transform(top1_idx)
        top1_conf = y_prob_sk[np.arange(len(top1_idx)), top1_idx]
    else:
        top1_lbl  = le.inverse_transform(y_pred_sk)
        top1_conf = np.full_like(y_pred_sk, np.nan, dtype=float)

    ds_val_text = tf.data.Dataset.from_tensor_slices(X_val[:200]).batch(256)
    y_prob_k = keras_model.predict(ds_val_text, verbose=0)
    y_idx_k  = np.argmax(y_prob_k, axis=1)
    y_lbl_k  = le.inverse_transform(y_idx_k)

    val_df = pd.DataFrame({
        "text": X_val[:200],
        "true_label": le.inverse_transform(y_val[:200]),
        "pred_sklearn": top1_lbl[:200],
        "pred_sklearn_conf": top1_conf[:200],
        "pred_keras": y_lbl_k[:200],
        "pred_keras_conf": y_prob_k[np.arange(len(y_idx_k[:200])), y_idx_k[:200]]
    })
    val_df.to_csv(PRED_SAMPLE, index=False)

    # Label mapping
    label_map = {int(i): name for i, name in enumerate(class_names)}
    with open(LABELS_JSON, "w", encoding="utf-8") as f:
        json.dump(label_map, f, indent=2, ensure_ascii=False)

    # Metrics + Config
    metrics = {
        "sklearn": {"accuracy": acc_sk, "f1_weighted": f1_sk, "top3_accuracy": top3_sk},
        "keras":   {"accuracy": acc_keras, "top3_accuracy": top3_keras, "epochs_trained": int(len(hist.history.get('loss', [])))},
        "n_classes": int(len(class_names)),
        "n_rows": int(len(df))
    }
    with open(METRICS_JSON, "w", encoding="utf-8") as f:
        json.dump(metrics, f, indent=2, ensure_ascii=False)

    cfg = {
        "data_path": CSV_PATH,
        "artifact_dir": ARTIFACT_DIR,
        "label_column": label_col,
        "text_columns_used": text_cols,
        "models": {
            "sklearn_pipeline_pkl": os.path.basename(PKL_PATH),
            "keras_model_h5": os.path.basename(H5_PATH)
        },
        "label_mapping_json": os.path.basename(LABELS_JSON),
        "training": {
            "sklearn": {"tfidf_max_features": 100_000, "ngram_range": [1, 2]},
            "keras": {"vocab_size": 40_000, "max_len": 128, "epochs_max": 25}
        }
    }
    with open(CONFIG_YAML, "w", encoding="utf-8") as f:
        yaml.safe_dump(cfg, f, sort_keys=False, allow_unicode=True)

    # === PLOTS ===
    # 1) Accuracy curve (Train/Val)
    plot_accuracy(HISTORY_CSV, ACC_PNG, also_show=True)

    # 2) Confusion matrix heatmap (Top-25 classes by frequency)
    #    Use KERAS predictions for confusion since we trained on keras history.
    #    Prepare keras predictions on full validation set:
    ds_val_all_text = tf.data.Dataset.from_tensor_slices(X_val).batch(256)
    y_prob_val_k = keras_model.predict(ds_val_all_text, verbose=0)
    y_pred_val_k = np.argmax(y_prob_val_k, axis=1)
    plot_confusion_heatmap(
        y_true=y_val,
        y_pred=y_pred_val_k,
        class_names=class_names,
        out_png=HEATMAP_PNG,
        top_k=25,
        also_show=True
    )

    logging.info("=== ArtGenie: Training + Plots DONE ===")
    logging.info(f"Saved:\n- {ACC_PNG}\n- {HEATMAP_PNG}\n- {HISTORY_CSV}\n- {CONF_FULL_CSV}")
    logging.info(f"Models/Meta:\n- {PKL_PATH}\n- {H5_PATH}\n- {METRICS_JSON}\n- {CONFIG_YAML}\n- {PRED_SAMPLE}\n- {LABELS_JSON}")

if __name__ == "__main__":
    main()
# Out:
# 2025-08-31 11:23:07,952 | INFO | Reading CSV: C:\Users\sagni\Downloads\Art Genie\archive\wikiart_scraped.csv
# 2025-08-31 11:23:08,647 | INFO | Using label column: 'style'
# 2025-08-31 11:23:08,648 | INFO | Using text columns: ['style', 'artist']
# 2025-08-31 11:23:09,200 | INFO | Filtered 46 rows due to rare classes (<8). Remaining classes: 201
# 2025-08-31 11:23:09,224 | INFO | Num classes: 201
# 2025-08-31 11:23:09,267 | INFO | [SKLEARN] Fitting TF-IDF + LogisticRegression...
# 2025-08-31 11:23:48,984 | INFO | [SKLEARN] Saved → C:\Users\sagni\Downloads\Art Genie\artgenie_textclf.pkl
# 2025-08-31 11:23:48,985 | INFO | [KERAS] Building & training text classifier...
# 2025-08-31 11:29:15,959 | WARNING | You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2025-08-31 11:29:16,135 | INFO | [KERAS] Saved → C:\Users\sagni\Downloads\Art Genie\artgenie_textclf.h5
# 2025-08-31 11:29:19,545 | INFO | === ArtGenie: Training + Plots DONE ===
# 2025-08-31 11:29:19,546 | INFO | Saved:
# - C:\Users\sagni\Downloads\Art Genie\accuracy_curve.png
# - C:\Users\sagni\Downloads\Art Genie\confusion_heatmap_top25.png
# - C:\Users\sagni\Downloads\Art Genie\history.csv
# - C:\Users\sagni\Downloads\Art Genie\confusion_matrix_full.csv
# 2025-08-31 11:29:19,546 | INFO | Models/Meta:
# - C:\Users\sagni\Downloads\Art Genie\artgenie_textclf.pkl
# - C:\Users\sagni\Downloads\Art Genie\artgenie_textclf.h5
# - C:\Users\sagni\Downloads\Art Genie\metrics.json
# - C:\Users\sagni\Downloads\Art Genie\artgenie_config.yaml
# - C:\Users\sagni\Downloads\Art Genie\sample_predictions.csv
# - C:\Users\sagni\Downloads\Art Genie\label_mapping.json
